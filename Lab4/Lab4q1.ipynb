# %%
import random
import matplotlib.pyplot as plt

# %%
# Utility functions 
def compute_mean(data):
    return sum(data) / len(data)

def compute_variance(data):
    mean = compute_mean(data)
    return sum((x - mean) ** 2 for x in data) / len(data)

# %%
# Dice rolling experiment
def roll_dice(num_rolls):
    """Simulate rolling a fair 6-sided die num_rolls times and return the sum."""
    return sum(random.randint(1, 6) for _ in range(num_rolls))

def dice_experiment(num_rolls, num_experiments):
    """Perform num_experiments of rolling a die num_rolls times, return sums list."""
    results = [roll_dice(num_rolls) for _ in range(num_experiments)]
    return results

# %%
# Plotting function 
def plot_histogram(data, title, bins=20):
    plt.hist(data, bins=bins, edgecolor='black', alpha=0.7)
    plt.title(title)
    plt.xlabel("Sum of Rolls")
    plt.ylabel("Frequency")
    plt.show()

# %%
# Main Experiment
num_experiments_list = [100, 500, 1000, 5000, 10000, 50000, 100000]

for rolls in [1, 2, 3]:  
    for n_exp in num_experiments_list:
        results = dice_experiment(rolls, n_exp)
        mean_val = compute_mean(results)
        var_val = compute_variance(results)
        print(f"Rolls: {rolls}, Experiments: {n_exp}, Mean: {mean_val:.2f}, Variance: {var_val:.2f}")
        plot_histogram(results, f"Histogram of {rolls} Rolls ({n_exp} Experiments)")
# Out:
# Rolls: 1, Experiments: 100, Mean: 3.58, Variance: 2.56
# Rolls: 1, Experiments: 500, Mean: 3.50, Variance: 2.95
# Rolls: 1, Experiments: 1000, Mean: 3.59, Variance: 2.98
# Rolls: 1, Experiments: 5000, Mean: 3.42, Variance: 2.94
# Rolls: 1, Experiments: 10000, Mean: 3.51, Variance: 2.92
# Rolls: 1, Experiments: 50000, Mean: 3.51, Variance: 2.90
# Rolls: 1, Experiments: 100000, Mean: 3.50, Variance: 2.92
# Rolls: 2, Experiments: 100, Mean: 6.98, Variance: 5.70
# Rolls: 2, Experiments: 500, Mean: 6.85, Variance: 5.74
# Rolls: 2, Experiments: 1000, Mean: 7.02, Variance: 5.46
# Rolls: 2, Experiments: 5000, Mean: 6.91, Variance: 5.92
# Rolls: 2, Experiments: 10000, Mean: 7.02, Variance: 5.86
# Rolls: 2, Experiments: 50000, Mean: 7.00, Variance: 5.85
# Rolls: 2, Experiments: 100000, Mean: 7.02, Variance: 5.85
# Rolls: 3, Experiments: 100, Mean: 10.28, Variance: 8.28
# Rolls: 3, Experiments: 500, Mean: 10.40, Variance: 8.60
# Rolls: 3, Experiments: 1000, Mean: 10.58, Variance: 8.68
# Rolls: 3, Experiments: 5000, Mean: 10.46, Variance: 8.78
# Rolls: 3, Experiments: 10000, Mean: 10.50, Variance: 8.69
# Rolls: 3, Experiments: 50000, Mean: 10.50, Variance: 8.71
# Rolls: 3, Experiments: 100000, Mean: 10.49, Variance: 8.82
